# %% [markdown]
# # Network analysis of DEGs from Dengue vaccine study
#
# High and Low responders
# Day 2, 4, and 7

# %%
import numpy as np
import networkx as nx
import pandas as pd
import random
print(np.__version__)
print(nx.__version__)
print(pd.__version__)

import sys
# Out:
# 1.19.2
# 2.5
# 1.1.3

# %% [markdown]
# # Load Interactome

# %%
# load STRING high confidence (>0.7) interactome
import ndex2
interactome_uuid='275bd84e-3d18-11e8-a935-0ac135e8bacf'
ndex_server='public.ndexbio.org'
ndex_user=None
ndex_password=None
G_STR = ndex2.create_nice_cx_from_server(
            ndex_server, 
            username=ndex_user, 
            password=ndex_password, 
            uuid=interactome_uuid
        ).to_networkx()
nodes = list(G_STR.nodes)

# print out interactome number of nodes and edges
print('number of nodes:')
print(len(G_STR.nodes))
print('\nnumber of edges:')
print(len(G_STR.edges))
# Out:
# number of nodes:
# 17185
#
# number of edges:
# 420534

# %%
str_nodes = list(G_STR.nodes)
print(len(str_nodes))
# Out:
# 17185

# %% [markdown]
# # Load differential expression results

# %%
DE_df = pd.read_csv('All_gene_list/All_H_combined.csv',index_col='X1')
print(len(DE_df))
DE_df.head()
# Out:
# 23735
#                  baseMean_d2  log2FoldChange_d2  lfcSE_d2   stat_d2  \
# X1
# ENSG00000000003    62.423235          -0.358307  0.253881 -1.411319
# ENSG00000000419  2886.588467          -0.446053  0.140282 -3.179679
# ENSG00000000457  3047.608158          -0.145559  0.114969 -1.266073
# ENSG00000000460   978.250107          -0.098610  0.076600 -1.287337
# ENSG00000000938  4511.025998           0.212165  0.157771  1.344763
#
#                  pvalue_d2   padj_d2  baseMean_d4  log2FoldChange_d4  \
# X1
# ENSG00000000003   0.158150  0.374575    68.818943          -0.203340
# ENSG00000000419   0.001474  0.041118  3191.354321          -0.133324
# ENSG00000000457   0.205487  0.433983  3197.072616          -0.000606
# ENSG00000000460   0.197977  0.425126  1069.894272           0.154703
# ENSG00000000938   0.178702  0.401600  3900.511416          -0.205638
#
#                  lfcSE_d4   stat_d4  ...   stat_d7  pvalue_d7   padj_d7  \
# X1                                   ...
# ENSG00000000003  0.316930 -0.641593  ... -1.779694   0.075126  0.621747
# ENSG00000000419  0.165481 -0.805674  ... -1.584913   0.112986  0.699833
# ENSG00000000457  0.116162 -0.005213  ... -0.366566   0.713943  0.973381
# ENSG00000000460  0.093207  1.659774  ...  1.214943   0.224388  0.818060
# ENSG00000000938  0.153032 -1.343761  ...  0.215744   0.829187  0.987168
#
#                  baseMean_d92  log2FoldChange_d92  lfcSE_d92  stat_d92  \
# X1
# ENSG00000000003     64.963139           -0.643644   0.279847 -2.299981
# ENSG00000000419   3503.724584           -0.122433   0.192407 -0.636324
# ENSG00000000457   3260.484083           -0.207950   0.125599 -1.655667
# ENSG00000000460   1079.672796           -0.064842   0.116255 -0.557759
# ENSG00000000938   5947.059683            0.670794   0.197011  3.404860
#
#                  pvalue_d92  padj_d92      name
# X1
# ENSG00000000003    0.021449  0.075060    TSPAN6
# ENSG00000000419    0.524565  0.683095      DPM1
# ENSG00000000457    0.097789  0.222208     SCYL3
# ENSG00000000460    0.577009  0.725165  C1orf112
# ENSG00000000938    0.000662  0.005586       FGR
#
# [5 rows x 25 columns]

# %%
# merge in data from other comparison
DE_df_L = pd.read_csv('All_gene_list/All_L_combined.csv',index_col='X1')

DE_df = DE_df.join(DE_df_L,lsuffix='_H',rsuffix='_L')
DE_df.head()
# Out:
#                  baseMean_d2_H  log2FoldChange_d2_H  lfcSE_d2_H  stat_d2_H  \
# X1
# ENSG00000000003      62.423235            -0.358307    0.253881  -1.411319
# ENSG00000000419    2886.588467            -0.446053    0.140282  -3.179679
# ENSG00000000457    3047.608158            -0.145559    0.114969  -1.266073
# ENSG00000000460     978.250107            -0.098610    0.076600  -1.287337
# ENSG00000000938    4511.025998             0.212165    0.157771   1.344763
#
#                  pvalue_d2_H  padj_d2_H  baseMean_d4_H  log2FoldChange_d4_H  \
# X1
# ENSG00000000003     0.158150   0.374575      68.818943            -0.203340
# ENSG00000000419     0.001474   0.041118    3191.354321            -0.133324
# ENSG00000000457     0.205487   0.433983    3197.072616            -0.000606
# ENSG00000000460     0.197977   0.425126    1069.894272             0.154703
# ENSG00000000938     0.178702   0.401600    3900.511416            -0.205638
#
#                  lfcSE_d4_H  stat_d4_H  ...  stat_d7_L  pvalue_d7_L  \
# X1                                      ...
# ENSG00000000003    0.316930  -0.641593  ...   0.598048     0.549808
# ENSG00000000419    0.165481  -0.805674  ...   0.377600     0.705728
# ENSG00000000457    0.116162  -0.005213  ...   0.020166     0.983911
# ENSG00000000460    0.093207   1.659774  ...   1.235782     0.216540
# ENSG00000000938    0.153032  -1.343761  ...  -0.335648     0.737136
#
#                  padj_d7_L  baseMean_d92_L  log2FoldChange_d92_L  lfcSE_d92_L  \
# X1
# ENSG00000000003   0.964334       53.785467             -0.135567     0.405983
# ENSG00000000419   0.979936     3238.472264              0.085125     0.239364
# ENSG00000000457   0.999656     3210.333444             -0.209093     0.158303
# ENSG00000000460   0.898405     1043.238710             -0.206621     0.174221
# ENSG00000000938   0.980556     5259.872771              0.796569     0.231908
#
#                  stat_d92_L  pvalue_d92_L  padj_d92_L    name_L
# X1
# ENSG00000000003   -0.333924      0.738437    0.891309    TSPAN6
# ENSG00000000419    0.355631      0.722117    0.883065      DPM1
# ENSG00000000457   -1.320841      0.186554    0.470328     SCYL3
# ENSG00000000460   -1.185970      0.235634    0.526840  C1orf112
# ENSG00000000938    3.434846      0.000593    0.013693       FGR
#
# [5 rows x 50 columns]

# %%
#set index
DE_df.set_index('name_H',inplace=True)

# %%
# subset by genes in the interactome
# --- STRING ----
loc_temp = list(np.intersect1d(DE_df.index.tolist(),str_nodes))
print(len(loc_temp))
DE_df = DE_df.loc[loc_temp]
DE_df = DE_df.sort_values('pvalue_d2_H')
DE_df.head()
# Out:
# 13194
#            baseMean_d2_H  log2FoldChange_d2_H  lfcSE_d2_H  stat_d2_H  \
# name_H
# MTRNR2L12     283.189169            -3.049662    0.477074  -6.392429
# SYNJ2BP      1772.696119            -1.765707    0.297711  -5.930936
# PPP2R1A       492.594283             0.778426    0.138359   5.626131
# MMGT1        1253.175777            -2.497730    0.445683  -5.604270
# TMEM43       3810.966317            -1.076232    0.193284  -5.568122
#
#             pvalue_d2_H  padj_d2_H  baseMean_d4_H  log2FoldChange_d4_H  \
# name_H
# MTRNR2L12  1.632711e-10   0.000003     434.505919            -0.010922
# SYNJ2BP    3.012124e-09   0.000016    2045.695393            -1.293452
# PPP2R1A    1.842964e-08   0.000055     342.740624            -0.205312
# MMGT1      2.091344e-08   0.000055    1496.836948            -1.845812
# TMEM43     2.574989e-08   0.000058    4373.984174            -0.458713
#
#            lfcSE_d4_H  stat_d4_H  ...  stat_d7_L   pvalue_d7_L  padj_d7_L  \
# name_H                            ...
# MTRNR2L12    0.210436  -0.051903  ...  -5.632087  1.780415e-08   0.000043
# SYNJ2BP      0.530650  -2.437486  ...   1.972453  4.855790e-02   0.697360
# PPP2R1A      0.179326  -1.144908  ...  -1.943526  5.195261e-02   0.699760
# MMGT1        0.459542  -4.016631  ...   0.347833  7.279655e-01   0.980089
# TMEM43       0.274429  -1.671514  ...   1.350858  1.767410e-01   0.873095
#
#            baseMean_d92_L  log2FoldChange_d92_L  lfcSE_d92_L  stat_d92_L  \
# name_H
# MTRNR2L12      141.624681             -2.766781     0.562129   -4.921966
# SYNJ2BP       1935.908347              0.087612     0.309882    0.282726
# PPP2R1A        542.984949              0.325529     0.313250    1.039198
# MMGT1         1376.018861             -0.319524     0.474236   -0.673766
# TMEM43        2891.388575              0.075608     0.289864    0.260838
#
#            pvalue_d92_L  padj_d92_L     name_L
# name_H
# MTRNR2L12  8.567905e-07    0.000163  MTRNR2L12
# SYNJ2BP    7.773869e-01    0.907170    SYNJ2BP
# PPP2R1A    2.987125e-01    0.590928    PPP2R1A
# MMGT1      5.004599e-01    0.755746      MMGT1
# TMEM43     7.942174e-01    0.914828     TMEM43
#
# [5 rows x 49 columns]

# %%
# take the union of DEGs of H and L per day
# adjusted p-value < 0.05 and log2FC > 1

DE_sig = DE_df[(DE_df['padj_d2_H']<0.05)&(DE_df['log2FoldChange_d2_H'].abs()>1)].index.tolist()
print(len(np.unique(DE_sig)))
DE_sig = DE_sig + DE_df[(DE_df['padj_d2_L']<0.05)&(DE_df['log2FoldChange_d2_L'].abs()>1)].index.tolist()
print(len(np.unique(DE_sig)))
DE_sig = DE_sig + DE_df[(DE_df['padj_d4_H']<0.05)&(DE_df['log2FoldChange_d4_H'].abs()>1)].index.tolist()
print(len(np.unique(DE_sig)))
DE_sig = DE_sig + DE_df[(DE_df['padj_d4_L']<0.05)&(DE_df['log2FoldChange_d4_L'].abs()>1)].index.tolist()
print(len(np.unique(DE_sig)))
DE_sig = DE_sig + DE_df[(DE_df['padj_d7_H']<0.05)&(DE_df['log2FoldChange_d7_H'].abs()>1)].index.tolist()
print(len(np.unique(DE_sig)))
DE_sig = DE_sig + DE_df[(DE_df['padj_d7_L']<0.05)&(DE_df['log2FoldChange_d7_L'].abs()>1)].index.tolist()
print(len(np.unique(DE_sig)))


DE_sig = list(np.unique(DE_sig))

print(len(DE_sig))
print(', '.join(DE_sig))
# Out:
# 121
# 283
# 305
# 310
# 371
# 388
# 388
# ACADS, ACKR1, ACO1, ACSBG1, ADCK1, AHNAK, AK1, ALKBH7, ANKRD9, ARL11, ARMC6, ARMCX2, ASL, AURKAIP1, B3GNT2, B3GNT5, B3GNT8, B4GALT2, B4GALT7, BASP1, BCL11B, BICC1, BLVRB, BMP1, BOLA2B, BTG2, C5AR1, CACNA1I, CCDC134, CCL2, CCL5, CCL8, CCND2, CCR1, CCRL2, CD151, CD68, CDAN1, CDC34, CDK3, CDKN1C, CHMP1A, CHST11, CISD2, CISD3, CITED2, CMPK2, CMTM3, CMTM5, CNTF, COMMD5, COX14, COX16, CPSF1, CREB5, CRIPT, CRKL, CROCC, CSRNP1, CTSW, CTXN2, CUEDC2, CXCL10, CXCL11, CXCR5, CYB561, CYB5D1, CYBA, CYC1, CYP4F3, CYSTM1, DBI, DCHS1, DDX58, DDX60, DERL3, DGCR6L, DGKI, DMAP1, DMTN, DNAAF2, DNAJB2, DNAJC5, DTX4, DYRK1B, DYRK3, DZIP1, E2F1, EBP, EGFL8, EIF2AK2, EIF4EBP1, ELOF1, EPSTI1, ERGIC1, ETV7, EVI5L, EXOSC6, FAHD1, FAM199X, FAM220A, FAM83D, FANK1, FAP, FARP1, FAU, FBXO45, FBXO6, FBXW5, FKBP8, FKBPL, FLNA, FLT3LG, FRMD3, GBP1, GBP6, GEMIN6, GIPC1, GIT1, GNA13, GPBAR1, GPD1L, GPR153, GPR37L1, GPR84, GPS1, GPX4, GSDMD, GSE1, GSTP1, GUK1, HBA1, HBA2, HBM, HERC5, HERC6, HESX1, HIST1H3E, HIST1H4E, HJURP, HK3, HOPX, HSPA6, IFI35, IFI44, IFI44L, IFI6, IFIH1, IFIT1, IFIT2, IFIT3, IFIT5, IL17RA, IMPG1, INHBA, INTS5, IRF7, ISG15, ITM2C, JAZF1, JUNB, JUND, KCNE2, KCNRG, KIAA1143, KLF1, KLF9, KLHL11, LAMP3, LAP3, LAT, LENG1, LGALS1, LIMD1, LLPH, LMF1, LMO2, LRRC8D, LY6E, LY6G6F, MAPK13, MARC2, MARCO, MATK, MAVS, MB21D2, MEX3C, MID1IP1, MIIP, MINK1, MLLT11, MLLT6, MMGT1, MOB2, MON1B, MORN1, MRPL11, MRPL14, MRPL34, MRPL36, MRPL49, MRPL53, MRPL54, MRPS12, MTRNR2L1, MTRNR2L12, MX1, MYBL2, MYL5, MYL6B, MYOF, MYZAP, MZB1, NAGLU, NAT8, NDUFC2, NDUFS8, NEU3, NPHP4, NR2C2AP, NT5M, OAS2, OASL, OBSCN, OCLN, OLIG2, ORM1, OSBPL5, PANK3, PARP12, PARP14, PARP9, PARVB, PAWR, PCYT2, PDZD4, PDZK1IP1, PGAM5, PGBD4, PILRB, PKN1, PLEC, PLSCR1, PLXNB2, PMVK, PNP, PNPLA2, PNPT1, POLE3, POLR2F, POLR2L, POLRMT, PPFIA4, PPP4C, PRDX2, PRKX, PSMB10, PSMD9, PTGDR2, PTGIR, PTOV1, PTPN14, PTPN18, PTPRR, PYGB, R3HDM4, RAB21, RAB37, RAB39A, RABAC1, RAP2B, RASSF3, RBBP9, RBM38, RELL2, RENBP, RFXANK, RHBDF2, RHOC, RILP, RMI1, RNF144B, RNF217, RNF5, RPL13, RPL36, RPLP2, RRAS, RRP9, RSAD2, RSL24D1, RUFY4, RUSC2, S1PR1, SAP30L, SAYSD1, SELENBP1, SEPT5, SERF2, SERPING1, SGPP1, SH3BGRL, SH3GLB2, SIGLEC1, SLC12A5, SLC2A6, SLC35B2, SLC38A7, SLC5A10, SLC6A8, SMTNL1, SNTB1, SNX21, SOCS5, SPATS2L, SRXN1, SSBP4, STAB1, SYNGR2, SYNJ2BP, SZRD1, TBC1D10C, TBCC, TCEAL1, TCEAL4, THBS2, TIMM13, TMEM170B, TMEM203, TMEM205, TMEM256, TMEM43, TNFRSF25, TNFSF10, TNFSF4, TNS1, TOMM22, TOR1B, TRIM14, TRIM5, TRMT1, TRMT2A, TSTA3, TTI2, TUBA1B, TUBA8, TUFM, TYMP, TYROBP, UBB, UBE2C, UBXN6, UNC119B, UNC45A, UNC93B1, USP18, USP20, USP41, VMA21, VPS37C, WASH2P, WDFY1, WDR18, WDR74, WDR89, WIPF2, XAF1, ZBP1, ZBTB17, ZBTB3, ZC3H10, ZC4H2, ZCCHC10, ZFP3, ZKSCAN7, ZNF138, ZNF213, ZNF251, ZNF441, ZNF460, ZNF563, ZNF605, ZNF627, ZNF674, ZNF764, ZNF775, ZNF790, ZNF92

# %% [markdown]
# # Export node and edge tables for cytoscape clustering

# %%
# ----- STRING -----
G_sub = nx.subgraph(G_STR,DE_sig)
print(len(list(G_sub.nodes)))
print(len(list(G_sub.edges)))
# Out:
# 388
# 655

# %%
DE_df.loc[DE_sig].to_csv('nodeLists/DE_nodeList_HandL_union_days247_210324.txt',sep='\t')

# %%
# write out nodelists and edgelists for overlap
z3_e1,z3_e2 = zip(*list(G_sub.edges))
edgelist_df = pd.DataFrame()
# add self edges so we don't lose nodes on import
edgelist_df['node1']=list(z3_e1)+list(G_sub.nodes)
edgelist_df['node2']=list(z3_e2)+list(G_sub.nodes)
edgelist_df.to_csv('edgeLists/DE_edgelist_HandL_union_days247_210324.txt',sep='\t')
print(len(edgelist_df))
